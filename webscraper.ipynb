# %% [markdown]
# ## 1) Scraping REvil
# REvil link: http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion

# %%
# Importing modules

import socks
import socket
import requests
from bs4 import BeautifulSoup

# %%
# Configuring Socks to use Tor

from urllib.request import urlopen
socks.set_default_proxy(socks.SOCKS5, "localhost", 9150)

old_socket = socket.socket # saving old socket info 
socket.socket = socks.socksocket

# %%
# It is necessary to use Tor for DNS resolution of Onion websites

def getaddrinfo(*args):
    return [(socket.AF_INET, socket.SOCK_STREAM, 6, '', (args[0], args[1]))]

socket.getaddrinfo = getaddrinfo

# %%
# Using requests package to read in the Hidden Wiki Onion Website on the Darknet

REvil_link = "http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion"
res = requests.get(REvil_link)

# %%
# Using beautifulsoup to get the website content into a nice format

soup = BeautifulSoup(res.content, 'html.parser')

# %%
# Having a look at the Website content

#print(soup.prettify())

# %%
# Checking the Website's title

soup.title
print(soup.title)
# Out:
# <title>Happy Blog </title>

# %%
# Getting all links out of the soup and deleting None's

links = [link.get('href') for link in soup.find_all('a', href=True)]
links = list(filter(None, links))
links
# Out:
# ['/',
#  '/posts/401',
#  '/posts/394',
#  '/posts/402',
#  '/posts/386',
#  'https://privatlab.org/s/v/4jjxzReyRgCj6lrn5yOd',
#  '/posts/375',
#  '/posts/384',
#  'http://www.inocean.no',
#  '/posts/393',
#  'http://www.hxfive.com',
#  '/posts/399',
#  'https://www.daylesford.com',
#  'https://thewildrabbit.co.uk',
#  '/posts/400',
#  '/posts/373',
#  '/?page=',
#  '/?page=1',
#  '/?page=2',
#  '/?page=3',
#  '/?page=4',
#  '/?page=5',
#  '/?page=6',
#  '/?page=7',
#  '/?page=8',
#  '/?page=9',
#  '/?page=10',
#  '/?page=11',
#  '/?page=12',
#  '/?page=13',
#  '/?page=14',
#  '/?page=15',
#  '/?page=16',
#  '/?page=17',
#  '/?page=18',
#  '/?page=19',
#  '/?page=20',
#  '/?page=21',
#  '/?page=22',
#  '/?page=23',
#  '/?page=24',
#  '/?page=25',
#  '/?page=2',
#  '/rss']

# %%
# testing for general links
'''
links = []
anchor_tags = soup.find_all('a')
for tag in anchor_tags:
    links.append(tag.text)
print(links)
'''
# Out:
# "\nlinks = []\nanchor_tags = soup.find_all('a')\nfor tag in anchor_tags:\n    links.append(tag.text)\nprint(links)\n"

# %%
# Saving all links into a list

webpage_links = [] 
for l in links:
    if "page" in l:
        l = REvil_link + l
        webpage_links.append(l)
        
webpage_links = webpage_links[1:-1] # remvoving first and last element from list
webpage_links
# Out:
# ['http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=1',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=2',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=3',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=4',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=5',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=6',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=7',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=8',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=9',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=10',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=11',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=12',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=13',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=14',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=15',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=16',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=17',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=18',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=19',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=20',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=21',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=22',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=23',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=24',
#  'http://dnpscnbaix6nkwvystl3yxglz7nteicqrou3t75tpcc5532cztc46qyd.onion/?page=25']

# %%
# Finding by class name

posts = soup.find_all(class_ = "blog-post-title")
for post in posts:
    title = post.find('a')
    print(title.text)
# Out:
# Spiezle Architectural Group Inc.
# ensingerplastics.com
# South Carolina Legal Services breach
# lstaff.com / atworksprofessional / atworks.com
# Primo Water
# inocean.no / 2000 GB
# Hx5, LLC
# Daylesford - BHoldings - Bamford - The Wild Rabbit
# KASEYA ATTACK INFO
# kuk.de / KREBS + KIEFER / 500GB

# %%
REvilHeader_list = []
for link in webpage_links:
    res = requests.get(link)
    soup = BeautifulSoup(res.content, 'html.parser')
    posts = soup.find_all(class_ = "blog-post-title")
    
    for post in posts:
        title = post.find('a')
        REvilHeader_list.append(title.text)

REvilHeader_list
# takes awhile to append all titles to master_list
# Out:
# ['Spiezle Architectural Group Inc.',
#  'ensingerplastics.com',
#  'South Carolina Legal Services breach',
#  'lstaff.com / atworksprofessional / atworks.com',
#  'Primo Water',
#  'inocean.no / 2000 GB',
#  'Hx5, LLC',
#  'Daylesford - BHoldings - Bamford - The Wild Rabbit',
#  'KASEYA ATTACK INFO',
#  'kuk.de / KREBS + KIEFER / 500GB',
#  'neroindustry.com',
#  'Masmovil ibercom SA revenue 1.99 billion $',
#  'Vic Pharma Industry and Trade Ltd.',
#  'CYMZ ',
#  'Asfaltproductienijmegen',
#  'University Medical Center of Southern Nevada',
#  ' Transform SR Brands, LLC',
#  'Malcolm C Foy & Co Limited',
#  'Trasporti Internazionali Transmec s.p.a.',
#  'The Smith & Wollensky Restaurant Group, Inc.',
#  'French Connection',
#  'Dicky Smith & Co Inc',
#  'HAAI GmbH',
#  'Moore Stephens Cape Town',
#  'Feedback Technology Corp.',
#  'Whittlesey & Hadley',
#  '  WestCongress Insurance Services LLC',
#  "Obama's friend is a dirty pervert",
#  'Big data breach from Arnoff Moving & Storage',
#  'Big data breach from ESD Dienstleistungs Gruppe',
#  'Law Offices of Michael B. Brehne, P.A',
#  'Aspire/SOL/Willson/Sjk/Tendriade',
#  'Royal Resorts',
#  'Citroen Wells',
#  'Möbelstadt Sommerlad',
#  'Agile Property Holdings',
#  'angstrom automotive group',
#  'Iaffaldano, Shaw & Young LLP',
#  ' ENPOL LLC',
#  'CEC Vibration Products',
#  'Betenbough Homes',
#  'Allen, Dyer, Doppelt, & Gilchrist, P.A.',
#  'Apex America',
#  'GDS Gesellschaft für Datenverarbeitungssysteme ',
#  'Thackray Williams LLP Solicitors',
#  'Peter Müller GARTENGESTALTUNG GmbH',
#  'KEYENCE DEUTSCHLAND GmbH',
#  'Lydall Inc.',
#  'ASARCO LLC',
#  'Amfine Chemical Corporation ',
#  'https://galoninsurance.ca/',
#  'JHK Legal',
#  'Treehouse hotels',
#  'Kajima corp',
#  'Habia Cable',
#  'govnet of fiji',
#  'mipharm.it',
#  'SOUTHERN ASPHALT',
#  'Thomas Concrete Group',
#  'PB Swiss Tools',
#  'boulos.com',
#  'Premi Beauty Industries',
#  'Oré Peinture',
#  'Fonds Finanz',
#  'EMC, Electric Motor and Contracting Co., Inc',
#  'Call Assist Ltd',
#  'Harold Marcus Ltd.',
#  'ReppertFactor, LLC.',
#  'Universal Group Inc.',
#  'RHA Health Service',
#  'NEO DERM GROUP LTD',
#  'Pierre Fabre Group',
#  'Fultz Maddox Dickens',
#  'Heartland Automotive, LLC',
#  'Honeywell International Inc.',
#  'Harris Federation',
#  'Varner & Brandt LLP',
#  'Tata Steel GROUP',
#  'Tristate Midstream',
#  'NorthWest , Insuranse Services',
#  'Maestri Murrell Commercial Real Estate',
#  'E. & J. Gallo Winery',
#  'Benetech, Inc.',
#  'MBA Group LTD',
#  'cockram2',
#  'Architectural Products of Virginia (apva.com)',
#  'Xchange Telecom - Brooklyn, NY - Inc.',
#  'Brownstein Rask LLP',
#  'Summit Credit Union BIG data breach',
#  'Milsoft Utility Solutions Inc big data breach',
#  'Acer Inc.',
#  'cockram',
#  ' Reno & Zahm LLP',
#  'Banco Inmobiliario Mexicano',
#  'TRIGANO, EUROPE’S NUMBER ONE FOR TRAILERS',
#  'Blazona Concrete Construction, Inc',
#  ' Ottawa, Kansas Cooperative Association',
#  'Union Bank of Nigeria',
#  'Wallin Hester, PLC',
#  'Standley Systems (standleys.com)',
#  'MJS Packaging Inc (mjspackaging.com)',
#  'RS Hughes Co Inc',
#  'Southern Arkansas University',
#  'D.M. BARONE SPA',
#  'Malcolm Drilling Company, Inc.',
#  'J & B Distributing Co.',
#  'Dailry Farm $30 billion revenue',
#  'SHELLY & SANDS, INC.',
#  'Resort Lifestyle Communities - DATA UPLOADED (2/5)',
#  'Jacobs Vanaman Agency Insurance',
#  'SOUTHERN CONCRETE & CONSTRUCTION, INC.',
#  ' General Insulation - DATA UPLOADED (2/5)',
#  ' Reese , Pyle , Drake & Meyer , P.L.L',
#  'UCAR.FR',
#  'weilandlogistics.com',
#  'Ghilotti Bros. Inc  ',
#  'Preferred Home Care',
#  'HUBER+SUHNER',
#  'Ficosa',
#  'axiomstone.co.uk ',
#  'PROOFS FOR KENNETH COPELAND',
#  '#PRESS RELEASE 2 - Kenneth Copeland',
#  'Trevor Sorbie',
#  'Bentek ',
#  ' Cardinal Logistics',
#  'FDR & CP SERVICES',
#  'RMD Kwikform - 1b Revenue',
#  'HEKEMIAN',
#  'https://local881ufcw.org/',
#  'fm-advogados.com.br',
#  'ctag.com',
#  'argentina.gob.ar',
#  '#PRESS RELEASE: Kenneth Copeland',
#  'Darby Group',
#  'nexiamelbourne.com.au',
#  'ILG.COM.AU',
#  ' CMC Consulting',
#  'WORLD LOGISTICS USA INC',
#  'Beacon Health Solutions, LLC (UPDATE 06/11/2020)',
#  'TheLeeco',
#  'Richardson',
#  "New Jersey Dental Hygienists' Association",
#  'GPIGAMING.COM',
#  'Hartz Mountain Industries',
#  'ANSA McAL Update#1',
#  'www.matson.com',
#  'Arapahoe Libraries Revenue $50 million',
#  'SHIONOGI & CO., LTD Revenue  $3.01 billion  ',
#  'www.braskem.com.br',
#  'Chesters International 100 GB',
#  'ANSA McAL',
#  'UMI1 (02.11.2020 update)',
#  'ESII',
#  'HERITAGE RECOURCE MANAGMENT LLC',
#  'JCI Industries',
#  'Deltrol 450 GB',
#  'MARTIN',
#  'MORRIS PETROLEUM Inc.',
#  '$5,5M Vard Group AS Fraudulent Recovery with Revil',
#  'NWLIC New chapter',
#  'High Mark Real Estate',
#  'Russell,Kraft&Gruber',
#  'Synsam Group AB revenue $366 million',
#  'taylorfarms.com',
#  'BROWN FORMAN CORPOTAION PART 2',
#  'National (?) Western Life',
#  'MEINHARDT - 2 Billions revenue',
#  'DXP Enterprises, Inc. | DXPE NASDAQ  $19.02',
#  'taylorfarms.com',
#  'Sampoerna Agro',
#  'Agrosuper',
#  'eurecat.com and     4datanet.com',
#  'Amicorp Group',
#  'National Western Life',
#  'Elsa LLC',
#  'National western life',
#  'eurecat.com',
#  'quest-worldwide.com',
#  'BROWN-FORMAN CORPORATION',
#  'australian company ARAFMI',
#  '4datanet.com',
#  'malabs.com',
#  'VIVA RESORTS',
#  'Schramm Inc.',
#  'CAT RICAMBI SRL Italy car sale company',
#  'allison',
#  'HAKUYOHIN',
#  'Brown Automotive Group Ltd',
#  'COTTONWOOD FINANCIAL INC',
#  'Actuaries and Associates Part 3',
#  'ODLO International AG',
#  'Actuaries and Associates Part 2',
#  'Adif (adif.es)',
#  'Genesis Products Inc.',
#  'Actuaries and Associates Part 1',
#  'Duncan Co (www.duncanco.com) Part 1',
#  'MAN België',
#  'FGXI',
#  'Silvaris',
#  'chempack.com.au',
#  'www.lionco.com',
#  'For press and public #4 (Lawyer case)',
#  'SPEC Inc',
#  'Snaptron Inc',
#  'GOODMANMINTZ (updated)',
#  'Hustech Installations AG hustech.ch ',
#  'Strategic Sites',
#  'Symbotic LLC Data leak',
#  'Universal Logistics Holdings',
#  'Scalepeople',
#  'Alaska General Seafoods & Leader Creek Fisheries',
#  'Symbotic LLC',
#  'Plaza Collection LTD',
#  'New feature: Auction',
#  'Agromart Group',
#  'Wartman Law Firm',
#  'Armour & Associates',
#  'Fraser Wheeler & Courtney LLP',
#  'CENTROID. Top Oracle Cloud Consulting Experts',
#  'Vierra Magen Marcus LLP',
#  'Plasmaterials Inc',
#  'For press #3 (Lawyer case)',
#  'For the press #2 and Trump.',
#  'insport.com.au',
#  'For press #1',
#  'Sherwood Food & Harvest Distributors',
#  'athrone.com',
#  'Patten & Prentice patten.co.uk',
#  'Groupe Cactus',
#  'M J Payne Ltd',
#  'TO Engineers',
#  'CINCINNATI CAPITAL CORPORATION',
#  'ASCENT Network',
#  'www.atlascars.com',
#  'HYMAN GROUP COMPANIES',
#  'www.cablex-group.com',
#  'NEDA USA',
#  'ehalc.com',
#  'CivicSmart (ex Duncan Technologies)',
#  'Geidi.com clients data',
#  'BURHANIGLASS.AE',
#  'jnbs',
#  'Brooks International',
#  'tirerama.com',
#  'VP Supply Corp',
#  'Kenneth Cole Productions',
#  'SoftwareOne.com']

# %% [markdown]
# ## 2) Selenium web automation to find victim industries

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(columns=['REvil Headers', 'Company Name', 'Indus', 'Location'])
df['REvil Headers'] = REvilHeader_list

df
# Out:
#                                       REvil Headers Companies Industries  \
# 0                  Spiezle Architectural Group Inc.       NaN        NaN
# 1                              ensingerplastics.com       NaN        NaN
# 2              South Carolina Legal Services breach       NaN        NaN
# 3    lstaff.com / atworksprofessional / atworks.com       NaN        NaN
# 4                                       Primo Water       NaN        NaN
# ..                                              ...       ...        ...
# 242                            Brooks International       NaN        NaN
# 243                                    tirerama.com       NaN        NaN
# 244                                  VP Supply Corp       NaN        NaN
# 245                        Kenneth Cole Productions       NaN        NaN
# 246                                 SoftwareOne.com       NaN        NaN
#
#     Location
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 242      NaN
# 243      NaN
# 244      NaN
# 245      NaN
# 246      NaN
#
# [247 rows x 4 columns]

# %%
# pip install webdriver-manager
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

socket.socket = old_socket # reuse the original socket for selenium

s=Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=s)
driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [/home/kali/.wdm/drivers/chromedriver/linux64/94.0.4606.61/chromedriver] found in cache

# %% [raw]
# # wikipedia search
# company_list = []
# industry_list = []
# location_list = []
# number = 0
#
# for header in REvilHeader_list:
#     driver.get('https://www.google.com')
#     search = driver.find_element(By.NAME, 'q')
#     search.send_keys(header + ' wikipedia')
#     search.send_keys(Keys.RETURN) # hit return after you enter search text
#
#     wiki_page = driver.find_element_by_tag_name('h3') # clicking the first search result
#     wiki_page.click()
#
#     try:
#         if "wikipedia" in driver.current_url:
#             company = driver.find_element_by_tag_name('h1')
#             company_list.append(company.text)
#
#             infobox = driver.find_elements_by_class_name("infobox-label")
#             infobox_data = driver.find_elements_by_class_name("infobox-data")
#
#             for info in infobox:
#                 if (info.text == "Industry"):
#                     industry = info.find_element_by_xpath("./following-sibling::td ").text
#                     industry_list.append(industry)
#                     break
#             else:
#                 industry_list.append(np.nan)
#
#             for info in infobox:
#                 if (info.text == "Headquarters"):
#                     location = info.find_element_by_xpath("./following-sibling::td ").text
#                     location_list.append(location)
#                     break
#             else:
#                 location_list.append(np.nan)
#         else:
#             company_list.append(np.nan)
#             industry_list.append(np.nan)
#             location_list.append(np.nan)
#
#     except Exception as e:
#         company_list.append(np.nan)
#         industry_list.append(np.nan)
#         location_list.append(np.nan)
#         print(e)
#     print(str(number) + ") " + header)
#     number = number + 1
#
# driver.quit()

# %%
# glassdoor search
company_list = []
industry_list = []
location_list = []
number = 0

for header in REvilHeader_list: 
    try:
        driver.get('https://www.google.com')
        search = driver.find_element(By.NAME, 'q')
        search.send_keys(header + ' glassdoor overview')
        search.send_keys(Keys.RETURN)
        glassdoor_page = driver.find_element_by_tag_name('h3') # clicking the first search result
        glassdoor_page.click()
        
        if "glassdoor" in driver.current_url:
            company = driver.find_element_by_tag_name('h1')
            company_list.append(company.text)
            
            pagesource = driver.page_source
            soup = BeautifulSoup(pagesource, 'html.parser')
            labels = soup.find_all('label')
            for label in labels:
                if (label.text == "Industry:"):
                    industry = label.next_sibling.text
                    industry_list.append(industry)
                    break
            else:
                industry_list.append(np.nan)
                
            for label in labels:
                if (label.text == "Headquarters:"):
                    location = label.next_sibling.text
                    location_list.append(location)
                    break
            else:
                location_list.append(np.nan)
        else:
            company_list.append(np.nan)
            industry_list.append(np.nan)
            location_list.append(np.nan)
    except Exception as e:
        company_list.append(np.nan)
        industry_list.append(np.nan)
        location_list.append(np.nan)
        print(e)

    print(str(number) + ") " + header)
    number = number + 1
    
driver.quit()
# Out:
# 0) Spiezle Architectural Group Inc.
# 1) ensingerplastics.com
# 2) South Carolina Legal Services breach
# 3) lstaff.com / atworksprofessional / atworks.com
# 4) Primo Water
# 5) inocean.no / 2000 GB
# 6) Hx5, LLC
# 7) Daylesford - BHoldings - Bamford - The Wild Rabbit
# 8) KASEYA ATTACK INFO
# 9) kuk.de / KREBS + KIEFER / 500GB
# 10) neroindustry.com
# 11) Masmovil ibercom SA revenue 1.99 billion $
# 12) Vic Pharma Industry and Trade Ltd.
# 13) CYMZ
# 14) Asfaltproductienijmegen
# 15) University Medical Center of Southern Nevada
# 16)  Transform SR Brands, LLC
# 17) Malcolm C Foy & Co Limited
# 18) Trasporti Internazionali Transmec s.p.a.
# 19) The Smith & Wollensky Restaurant Group, Inc.
# 20) French Connection
# 21) Dicky Smith & Co Inc
# 22) HAAI GmbH
# 23) Moore Stephens Cape Town
# 24) Feedback Technology Corp.
# 25) Whittlesey & Hadley
# 26)   WestCongress Insurance Services LLC
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1"}
#   (Session info: chrome=94.0.4606.61)
#
# 27) Obama's friend is a dirty pervert
# 28) Big data breach from Arnoff Moving & Storage
# 29) Big data breach from ESD Dienstleistungs Gruppe
# 30) Law Offices of Michael B. Brehne, P.A
# 31) Aspire/SOL/Willson/Sjk/Tendriade
# 32) Royal Resorts
# 33) Citroen Wells
# 34) Möbelstadt Sommerlad
# 35) Agile Property Holdings
# 36) angstrom automotive group
# 37) Iaffaldano, Shaw & Young LLP
# 38)  ENPOL LLC
# 39) CEC Vibration Products
# 40) Betenbough Homes
# 41) Allen, Dyer, Doppelt, & Gilchrist, P.A.
# 42) Apex America
# 43) GDS Gesellschaft für Datenverarbeitungssysteme
# 44) Thackray Williams LLP Solicitors
# 45) Peter Müller GARTENGESTALTUNG GmbH
# 46) KEYENCE DEUTSCHLAND GmbH
# 47) Lydall Inc.
# 48) ASARCO LLC
# 49) Amfine Chemical Corporation
# 50) https://galoninsurance.ca/
# 51) JHK Legal
# 52) Treehouse hotels
# 53) Kajima corp
# 54) Habia Cable
# 55) govnet of fiji
# 56) mipharm.it
# 57) SOUTHERN ASPHALT
# 58) Thomas Concrete Group
# 59) PB Swiss Tools
# 60) boulos.com
# 61) Premi Beauty Industries
# 62) Oré Peinture
# 63) Fonds Finanz
# 64) EMC, Electric Motor and Contracting Co., Inc
# 65) Call Assist Ltd
# 66) Harold Marcus Ltd.
# 67) ReppertFactor, LLC.
# 68) Universal Group Inc.
# 69) RHA Health Service
# 70) NEO DERM GROUP LTD
# 71) Pierre Fabre Group
# 72) Fultz Maddox Dickens
# 73) Heartland Automotive, LLC
# 74) Honeywell International Inc.
# 75) Harris Federation
# 76) Varner & Brandt LLP
# 77) Tata Steel GROUP
# 78) Tristate Midstream
# 79) NorthWest , Insuranse Services
# 80) Maestri Murrell Commercial Real Estate
# 81) E. & J. Gallo Winery
# 82) Benetech, Inc.
# 83) MBA Group LTD
# 84) cockram2
# 85) Architectural Products of Virginia (apva.com)
# 86) Xchange Telecom - Brooklyn, NY - Inc.
# 87) Brownstein Rask LLP
# 88) Summit Credit Union BIG data breach
# 89) Milsoft Utility Solutions Inc big data breach
# 90) Acer Inc.
# 91) cockram
# 92)  Reno & Zahm LLP
# 93) Banco Inmobiliario Mexicano
# 94) TRIGANO, EUROPE’S NUMBER ONE FOR TRAILERS
# 95) Blazona Concrete Construction, Inc
# 96)  Ottawa, Kansas Cooperative Association
# 97) Union Bank of Nigeria
# 98) Wallin Hester, PLC
# 99) Standley Systems (standleys.com)
# 100) MJS Packaging Inc (mjspackaging.com)
# 101) RS Hughes Co Inc
# 102) Southern Arkansas University
# 103) D.M. BARONE SPA
# 104) Malcolm Drilling Company, Inc.
# 105) J & B Distributing Co.
# 106) Dailry Farm $30 billion revenue
# 107) SHELLY & SANDS, INC.
# 108) Resort Lifestyle Communities - DATA UPLOADED (2/5)
# 109) Jacobs Vanaman Agency Insurance
# 110) SOUTHERN CONCRETE & CONSTRUCTION, INC.
# 111)  General Insulation - DATA UPLOADED (2/5)
# 112)  Reese , Pyle , Drake & Meyer , P.L.L
# 113) UCAR.FR
# 114) weilandlogistics.com
# 115) Ghilotti Bros. Inc
# 116) Preferred Home Care
# 117) HUBER+SUHNER
# 118) Ficosa
# 119) axiomstone.co.uk
# 120) PROOFS FOR KENNETH COPELAND
# 121) #PRESS RELEASE 2 - Kenneth Copeland
# 122) Trevor Sorbie
# 123) Bentek
# 124)  Cardinal Logistics
# 125) FDR & CP SERVICES
# 126) RMD Kwikform - 1b Revenue
# 127) HEKEMIAN
# 128) https://local881ufcw.org/
# 129) fm-advogados.com.br
# 130) ctag.com
# 131) argentina.gob.ar
# 132) #PRESS RELEASE: Kenneth Copeland
# 133) Darby Group
# 134) nexiamelbourne.com.au
# 135) ILG.COM.AU
# 136)  CMC Consulting
# 137) WORLD LOGISTICS USA INC
# 138) Beacon Health Solutions, LLC (UPDATE 06/11/2020)
# 139) TheLeeco
# 140) Richardson
# 141) New Jersey Dental Hygienists' Association
# 142) GPIGAMING.COM
# 143) Hartz Mountain Industries
# 144) ANSA McAL Update#1
# 145) www.matson.com
# 146) Arapahoe Libraries Revenue $50 million
# 147) SHIONOGI & CO., LTD Revenue  $3.01 billion
# 148) www.braskem.com.br
# 149) Chesters International 100 GB
# 150) ANSA McAL
# 151) UMI1 (02.11.2020 update)
# 152) ESII
# 153) HERITAGE RECOURCE MANAGMENT LLC
# 154) JCI Industries
# 155) Deltrol 450 GB
# 156) MARTIN
# 157) MORRIS PETROLEUM Inc.
# 158) $5,5M Vard Group AS Fraudulent Recovery with Revil
# 159) NWLIC New chapter
# 160) High Mark Real Estate
# 161) Russell,Kraft&Gruber
# 162) Synsam Group AB revenue $366 million
# 163) taylorfarms.com
# 164) BROWN FORMAN CORPOTAION PART 2
# 165) National (?) Western Life
# 166) MEINHARDT - 2 Billions revenue
# 167) DXP Enterprises, Inc. | DXPE NASDAQ  $19.02
# 168) taylorfarms.com
# 169) Sampoerna Agro
# 170) Agrosuper
# 171) eurecat.com and     4datanet.com
# 172) Amicorp Group
# 173) National Western Life
# 174) Elsa LLC
# 175) National western life
# 176) eurecat.com
# 177) quest-worldwide.com
# 178) BROWN-FORMAN CORPORATION
# 179) australian company ARAFMI
# 180) 4datanet.com
# 181) malabs.com
# 182) VIVA RESORTS
# 183) Schramm Inc.
# 184) CAT RICAMBI SRL Italy car sale company
# 185) allison
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1"}
#   (Session info: chrome=94.0.4606.61)
#
# 186) HAKUYOHIN
# 187) Brown Automotive Group Ltd
# 188) COTTONWOOD FINANCIAL INC
# 189) Actuaries and Associates Part 3
# 190) ODLO International AG
# 191) Actuaries and Associates Part 2
# 192) Adif (adif.es)
# 193) Genesis Products Inc.
# 194) Actuaries and Associates Part 1
# 195) Duncan Co (www.duncanco.com) Part 1
# 196) MAN België
# 197) FGXI
# 198) Silvaris
# 199) chempack.com.au
# 200) www.lionco.com
# 201) For press and public #4 (Lawyer case)
# 202) SPEC Inc
# 203) Snaptron Inc
# 204) GOODMANMINTZ (updated)
# 205) Hustech Installations AG hustech.ch
# 206) Strategic Sites
# 207) Symbotic LLC Data leak
# 208) Universal Logistics Holdings
# 209) Scalepeople
# 210) Alaska General Seafoods & Leader Creek Fisheries
# 211) Symbotic LLC
# 212) Plaza Collection LTD
# 213) New feature: Auction
# 214) Agromart Group
# 215) Wartman Law Firm
# 216) Armour & Associates
# 217) Fraser Wheeler & Courtney LLP
# 218) CENTROID. Top Oracle Cloud Consulting Experts
# 219) Vierra Magen Marcus LLP
# 220) Plasmaterials Inc
# 221) For press #3 (Lawyer case)
# 222) For the press #2 and Trump.
# 223) insport.com.au
# 224) For press #1
# 225) Sherwood Food & Harvest Distributors
# 226) athrone.com
# 227) Patten & Prentice patten.co.uk
# 228) Groupe Cactus
# 229) M J Payne Ltd
# 230) TO Engineers
# 231) CINCINNATI CAPITAL CORPORATION
# 232) ASCENT Network
# 233) www.atlascars.com
# 234) HYMAN GROUP COMPANIES
# 235) www.cablex-group.com
# 236) NEDA USA
# 237) ehalc.com
# 238) CivicSmart (ex Duncan Technologies)
# 239) Geidi.com clients data
# 240) BURHANIGLASS.AE
# 241) jnbs
# 242) Brooks International
# 243) tirerama.com
# 244) VP Supply Corp
# 245) Kenneth Cole Productions
# 246) SoftwareOne.com

# %% [raw]
# # linkedin search
# '''
# for company in master_list:
#     driver.get('https://www.google.com')
#     search = driver.find_element(By.NAME, 'q')
#     search.send_keys(company + ' linkedin')
#     search.send_keys(Keys.RETURN) # hit return after you enter search text
#
#     linkedin_page = driver.find_element_by_tag_name('h3') # clicking the first search result
#     linkedin_page.click()
#
#     try:
#         info_item = driver.find_elements_by_class_name("basic-info-item__term")
#         info_desc = driver.find_elements_by_class_name("basic-info-item__description")
#         index = 0
#         for info in info_item:
#             if (info.text == "Industries"):
#                 print(info_desc[index].text)
#             index = index + 1
#     except:
#         print("cb")
# '''

# %% [markdown]
# ## 3) Data cleaning

# %%
df['REvil Headers'] = REvilHeader_list
df['Companies'] = company_list
df['Industries'] = industry_list
df['Location'] = location_list

df
# Out:
#                                       REvil Headers  \
# 0                  Spiezle Architectural Group Inc.
# 1                              ensingerplastics.com
# 2              South Carolina Legal Services breach
# 3    lstaff.com / atworksprofessional / atworks.com
# 4                                       Primo Water
# ..                                              ...
# 242                            Brooks International
# 243                                    tirerama.com
# 244                                  VP Supply Corp
# 245                        Kenneth Cole Productions
# 246                                 SoftwareOne.com
#
#                          Companies                               Industries  \
# 0      Spiezle Architectural Group                             Construction
# 1                         Ensinger              Miscellaneous Manufacturing
# 2    South Carolina Legal Services                                      NaN
# 3                  AtWork! Reviews                                      NaN
# 4                      Primo Water               Food & Drink Manufacturing
# ..                             ...                                      ...
# 242   Brooks International Reviews                                      NaN
# 243                      Tire-Rama  Motor Vehicle Parts & Accessories Shops
# 244                      VP Supply                                Wholesale
# 245           Kenneth Cole Reviews                                      NaN
# 246            SoftwareONE Reviews                                      NaN
#
#                Location
# 0          Hamilton, NJ
# 1    Nufringen, Germany
# 2        Greenville, SC
# 3                   NaN
# 4     Winston-Salem, NC
# ..                  ...
# 242                 NaN
# 243        Billings, MT
# 244       Rochester, NY
# 245                 NaN
# 246                 NaN
#
# [247 rows x 4 columns]

# %%
df = df.dropna()
df = df.reset_index(drop=True) # reset index

df
# Out:
#                        REvil Headers                              Companies  \
# 0   Spiezle Architectural Group Inc.            Spiezle Architectural Group
# 1               ensingerplastics.com                               Ensinger
# 2                        Primo Water                            Primo Water
# 3               inocean.no / 2000 GB                               Innocean
# 4                           Hx5, LLC                                    HX5
# ..                               ...                                    ...
# 69                          NEDA USA  National Eating Disorders Association
# 70                   BURHANIGLASS.AE                      Burhani Engineers
# 71                              jnbs      Jamaica National Building Society
# 72                      tirerama.com                              Tire-Rama
# 73                    VP Supply Corp                              VP Supply
#
#                                  Industries               Location
# 0                              Construction           Hamilton, NJ
# 1               Miscellaneous Manufacturing     Nufringen, Germany
# 2                Food & Drink Manufacturing      Winston-Salem, NC
# 3                   Advertising & Marketing     Seoul, South Korea
# 4                       Aerospace & Defence  Fort Walton Beach, FL
# ..                                      ...                    ...
# 69                          Social Services           Seattle, 061
# 70      Architectural & Engineering Service         Nairobi, Kenya
# 71                                  Lending      Kingston, Jamaica
# 72  Motor Vehicle Parts & Accessories Shops           Billings, MT
# 73                                Wholesale          Rochester, NY
#
# [74 rows x 4 columns]
